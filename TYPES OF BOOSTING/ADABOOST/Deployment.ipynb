# %%
import pickle

# %%
loaded_model=pickle.load(open("finalized_model_ADABOOST_insurance.sav",'rb'))
result=loaded_model.predict([[1330,20.55,0,1,4]])
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([26387.57288333])
