# %%
import pickle

# %%
loaded_model=pickle.load(open("finalized_model_XGBOOST_insurance.sav",'rb'))
result=loaded_model.predict([[1330,20.55,0,1,4]])

# %%
result
# Out:
# array([22234.771], dtype=float32)
